# %% [markdown]
# # Load the packages

# %%
import os
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Load the data

# %%
train = pd.read_csv("Data/Train.csv", low_memory=False)
test = pd.read_csv("Data/Test.csv", low_memory=False)
sample_submission = pd.read_csv('Data/SampleSubmission.csv')

# %%
train.head()
# Out:
#        child_id  data_year  child_date  child_age child_enrolment_date  \
# 0  ID_SYSJ2FM0D     2022.0  2022-02-03  59.000000                  NaN
# 1  ID_J5BTFOZR3     2019.0         NaN  60.163933                  NaN
# 2  ID_R00SN7AUD     2022.0  2022-03-11  69.000000                  NaN
# 3  ID_BSSK60PAZ     2021.0  2021-10-13  53.000000           2020-01-15
# 4  ID_IZTY6TC4D     2021.0  2021-10-13  57.000000           2021-10-13
#
#    child_months_enrolment child_grant   child_years_in_programme  \
# 0                     NaN         NaN                        NaN
# 1                     NaN         NaN  1st year in the programme
# 2                     NaN         NaN                        NaN
# 3                    20.0          No  1st year in the programme
# 4                     0.0         NaN      2nd year in programme
#
#    child_height child_observe_attentive  ... obs_cooking_5 obs_cooking_6  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8585 entries, 0 to 8584
# Columns: 679 entries, child_id to target
# dtypes: float64(160), object(519)
# memory usage: 44.5+ MB

# %%
test.head()
# Out:
#        child_id  data_year  child_date  child_age child_enrolment_date  \
# 0  ID_0I0999N6S     2021.0  2021-09-20  57.000000                  NaN
# 1  ID_GQ6ONJ4FP     2021.0  2021-10-21  54.000000           2021-01-10
# 2  ID_YZ76CVRW3     2021.0  2021-05-17  57.000000                  NaN
# 3  ID_BNINCRXH8     2022.0  2022-09-09  59.334702                  NaN
# 4  ID_1U7GDTLRI     2021.0  2021-10-12  54.000000           2021-01-15
#
#    child_months_enrolment child_grant   child_years_in_programme  \
# 0                     NaN         Yes      2nd year in programme
# 1                     9.0         Yes  1st year in the programme
# 2                     NaN         Yes                        NaN
# 3                     NaN         NaN      3rd year in programme
# 4                     8.0         Yes  1st year in the programme
#
#    child_height child_observe_attentive  ... obs_cooking_4 obs_cooking_5  \
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3680 entries, 0 to 3679
# Columns: 678 entries, child_id to obs_heating_7
# dtypes: float64(161), object(517)
# memory usage: 19.0+ MB

# %%
sample_submission.head()
# Out:
#        child_id  target feature_1 feature_2 feature_3 feature_4 feature_5  \
# 0  ID_0I0999N6S       0   feature   feature   feature   feature   feature
# 1  ID_GQ6ONJ4FP       0   feature   feature   feature   feature   feature
# 2  ID_YZ76CVRW3       0   feature   feature   feature   feature   feature
# 3  ID_BNINCRXH8       0   feature   feature   feature   feature   feature
# 4  ID_1U7GDTLRI       0   feature   feature   feature   feature   feature
#
#   feature_6 feature_7 feature_8 feature_9 feature_10 feature_11 feature_12  \
# 0   feature   feature   feature   feature    feature    feature    feature
# 1   feature   feature   feature   feature    feature    feature    feature
# 2   feature   feature   feature   feature    feature    feature    feature
# 3   feature   feature   feature   feature    feature    feature    feature
# 4   feature   feature   feature   feature    feature    feature    feature
#
#   feature_13 feature_14 feature_15
# ...

# %%
sample_submission.head()
# Out:
#        child_id  target feature_1 feature_2 feature_3 feature_4 feature_5  \
# 0  ID_0I0999N6S       0   feature   feature   feature   feature   feature
# 1  ID_GQ6ONJ4FP       0   feature   feature   feature   feature   feature
# 2  ID_YZ76CVRW3       0   feature   feature   feature   feature   feature
# 3  ID_BNINCRXH8       0   feature   feature   feature   feature   feature
# 4  ID_1U7GDTLRI       0   feature   feature   feature   feature   feature
#
#   feature_6 feature_7 feature_8 feature_9 feature_10 feature_11 feature_12  \
# 0   feature   feature   feature   feature    feature    feature    feature
# 1   feature   feature   feature   feature    feature    feature    feature
# 2   feature   feature   feature   feature    feature    feature    feature
# 3   feature   feature   feature   feature    feature    feature    feature
# 4   feature   feature   feature   feature    feature    feature    feature
#
#   feature_13 feature_14 feature_15
# ...

# %%
sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3680 entries, 0 to 3679
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   child_id    3680 non-null   object
#  1   target      3680 non-null   int64
#  2   feature_1   3680 non-null   object
#  3   feature_2   3680 non-null   object
#  4   feature_3   3680 non-null   object
#  5   feature_4   3680 non-null   object
#  6   feature_5   3680 non-null   object
#  7   feature_6   3680 non-null   object
#  8   feature_7   3680 non-null   object
#  9   feature_8   3680 non-null   object
#  10  feature_9   3680 non-null   object
#  11  feature_10  3680 non-null   object
#  12  feature_11  3680 non-null   object
#  13  feature_12  3680 non-null   object
#  14  feature_13  3680 non-null   object
#  15  feature_14  3680 non-null   object
#  16  feature_15  3680 non-null   object
# dtypes: int64(1), object(16)
# memory usage: 488.9+ KB

# %%
variables_description = pd.read_csv("Data/VariableDescription.csv")
variables_description.head()
# Out:
#           Variable Name           Variable Label Answer Label
# 0              child_id          Unique child ID   Open ended
# 1             data_year  Year data was collected   Open ended
# 2            child_date                ELOM date   Open ended
# 3             child_age      Child age in months   Open ended
# 4  child_enrolment_date     Date enrolled in ELP   Open ended

# %% [markdown]
# For the above cells we learned that the train set has 8585 observations 679 columns with the data types: 160 are float64, 519 are object.
#
# Let's first make sure the data type of each column is the appropriate one.

# %%
# we select data types that are float first

train_number_df = train.select_dtypes('number').copy()

# %%
train_number_df
# Out:
#       data_year  child_age  child_months_enrolment  child_height  \
# 0        2022.0  59.000000                     NaN           NaN
# 1        2019.0  60.163933                     NaN    103.000000
# 2        2022.0  69.000000                     NaN    108.400002
# 3        2021.0  53.000000                    20.0     98.099998
# 4        2021.0  57.000000                     0.0    114.000000
# ...         ...        ...                     ...           ...
# 8580     2021.0  55.000000                     9.0    102.300003
# 8581     2021.0  55.000000                    32.0    102.599998
# 8582     2021.0  56.000000                    45.0    103.800003
# 8583     2021.0  57.000000                     9.0    102.400002
# 8584     2021.0  50.000000                     NaN    101.000000
#
#       child_observe_total  child_zha  child_attendance  ward_best  \
# 0                     4.0        NaN               NaN       39.0
# ...

# %% [markdown]
# data_year:  int
# child_age: ??
# child_months_enrolment : ??
# child_attendance : int
# war_best : ??

# %%
# view the full list of columns and check their meaning from the VariableDescription.csv

list(train_number_df.columns)
# Out:
# ['data_year',
#  'child_age',
#  'child_months_enrolment',
#  'child_height',
#  'child_observe_total',
#  'child_zha',
#  'child_attendance',
#  'ward_best',
#  'id_enumerator',
#  'id_facility',
#  'pqa_class_assistants',
#  'pqa_score_environment',
#  'pqa_score_assessment',
#  'pqa_score_relationships',
#  'pqa_score_curriculum',
#  'pqa_score_teaching',
#  'pra_experience',
#  'pra_class_present',
#  'pra_class_size',
#  'pra_class_attendance',
#  'pra_class_attendance_precovid',
#  'pra_hhsize',
#  'pra_measure_rectangle_length',
#  'pra_measure_rectangle_width',
#  'pra_class_space',
#  'pri_days',
#  'pri_time_open_hours',
#  'pri_time_open_minutes',
#  'pri_time_close_hours',
#  'pri_time_close_minutes',
#  'pri_year',
#  'pri_fees_amount',
#  'pri_dsd_year',
#  'pri_capacity',
#  'pri_amount_funding_dsd',
#  'pri_amount_funding_fees',
#  'pri_children_4_6_years',
#  'pri_difficult_see',
#  'pri_difficult_hear',
#  'pri_difficult_walk',
#  'pri_difficult_hold',
# ...
